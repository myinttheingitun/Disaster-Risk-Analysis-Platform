# %%
import pandas as pd


# big_df = pd.read_excel('/content/1900-2024_public_emdat_custom_request_2024-04-20_39efc9b7-44de-48fc-8353-bf01f2e06539.xlsx')
big_df = pd.read_excel('/content/2000-2024_public_emdat_custom_request_2024-04-21_e453b16f-3ab1-447c-8b91-47a2a3f9f355.xlsx')
big_df
# Out:
#             DisNo. Historic Classification Key Disaster Group  \
# 0    2000-0021-USA       No    nat-met-sto-tor        Natural
# 1    2000-0067-USA       No    nat-met-sto-tor        Natural
# 2    2000-0080-USA       No    nat-hyd-flo-riv        Natural
# 3    2000-0128-USA       No    nat-cli-wil-for        Natural
# 4    2000-0175-USA       No    nat-met-sto-tor        Natural
# ..             ...      ...                ...            ...
# 543  2023-0785-USA       No    nat-hyd-flo-flo        Natural
# 544  2023-0826-USA       No    nat-met-sto-sev        Natural
# 545  2023-0843-USA       No    nat-met-sto-sev        Natural
# 546  2024-0005-USA       No    nat-met-sto-bli        Natural
# 547  2024-0126-USA       No    nat-cli-wil-wil        Natural
#
#     Disaster Subgroup Disaster Type       Disaster Subtype External IDs  \
# 0      Meteorological         Storm                Tornado          NaN
# 1      Meteorological         Storm                Tornado          NaN
# 2        Hydrological         Flood         Riverine flood          NaN
# 3      Climatological      Wildfire            Forest fire          NaN
# 4      Meteorological         Storm                Tornado          NaN
# ..                ...           ...                    ...          ...
# 543      Hydrological         Flood        Flood (General)          NaN
# 544    Meteorological         Storm         Severe weather          NaN
# 545    Meteorological         Storm         Severe weather          NaN
# 546    Meteorological         Storm  Blizzard/Winter storm          NaN
# 547    Climatological      Wildfire     Wildfire (General)          NaN
#
#                                             Event Name  ISO  ...  \
# 0                                                  NaN  USA  ...
# 1                                                  NaN  USA  ...
# 2                                                  NaN  USA  ...
# 3                                                  NaN  USA  ...
# 4                                                  NaN  USA  ...
# ..                                                 ...  ...  ...
# 543                                                NaN  USA  ...
# 544                                                NaN  USA  ...
# 545                                                NaN  USA  ...
# 546                                                NaN  USA  ...
# 547   Smokehouse Creek, Windy Deuce and Grape Vine ...  USA  ...
#
#     Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# 0                               NaN                                       NaN
# 1                               NaN                                       NaN
# 2                               NaN                                       NaN
# 3                               NaN                                       NaN
# 4                               NaN                                       NaN
# ..                              ...                                       ...
# 543                             NaN                                       NaN
# 544                             NaN                                       NaN
# 545                             NaN                                       NaN
# 546                             NaN                                       NaN
# 547                             NaN                                       NaN
#
#     Insured Damage ('000 US$) Insured Damage, Adjusted ('000 US$)  \
# 0                    200500.0                            340751.0
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
# ..                        ...                                 ...
# 543                       NaN                                 NaN
# 544                       NaN                                 NaN
# 545                       NaN                                 NaN
# 546                       NaN                                 NaN
# 547                       NaN                                 NaN
#
#     Total Damage ('000 US$) Total Damage, Adjusted ('000 US$)        CPI  \
# 0                  210000.0                          356896.0  58.840648
# 1                       NaN                               NaN  58.840648
# 2                       NaN                               NaN  58.840648
# 3                       NaN                               NaN  58.840648
# 4                  450000.0                          764777.0  58.840648
# ..                      ...                               ...        ...
# 543                     NaN                               NaN        NaN
# 544                100000.0                               NaN        NaN
# 545               1300000.0                               NaN        NaN
# 546                     NaN                               NaN        NaN
# 547                     NaN                               NaN        NaN
#
#                                            Admin Units  Entry Date  \
# 0    [{"adm2_code":29698,"adm2_name":"Crittenden"},...  2003-07-01
# 1    [{"adm2_code":28696,"adm2_name":"Bullock"},{"a...  2005-04-24
# 2    [{"adm1_code":3231,"adm1_name":"Kentucky"},{"a...  2005-09-16
# 3    [{"adm2_code":28998,"adm2_name":"Alachua"},{"a...  2003-07-01
# 4    [{"adm2_code":31225,"adm2_name":"Burleson"},{"...  2003-07-01
# ..                                                 ...         ...
# 543                                                NaN  2023-12-07
# 544                                                NaN  2023-12-11
# 545                                                NaN  2023-12-19
# 546                                                NaN  2024-01-16
# 547                                                NaN  2024-03-11
#
#      Last Update
# 0     2023-09-25
# 1     2023-09-25
# 2     2023-09-25
# 3     2023-09-25
# 4     2023-09-25
# ..           ...
# 543   2023-12-08
# 544   2023-12-18
# 545   2024-02-28
# 546   2024-02-14
# 547   2024-04-03
#
# [548 rows x 46 columns]

# %%
df = big_df[["Disaster Group","Disaster Subgroup", "Disaster Subtype", "Location", "Start Year", "Total Deaths", "No. Injured", "Total Damage, Adjusted ('000 US$)"]].copy()
df['Location'] = df['Location'].astype(str)
df['Disaster Group'] = df['Disaster Group'].astype(str)
df['Disaster Subgroup'] = df['Disaster Subgroup'].astype(str)
df['Disaster Subtype'] = df['Disaster Subtype'].astype(str)
df
# Out:
#     Disaster Group Disaster Subgroup       Disaster Subtype  \
# 0          Natural    Meteorological                Tornado
# 1          Natural    Meteorological                Tornado
# 2          Natural      Hydrological         Riverine flood
# 3          Natural    Climatological            Forest fire
# 4          Natural    Meteorological                Tornado
# ..             ...               ...                    ...
# 543        Natural      Hydrological        Flood (General)
# 544        Natural    Meteorological         Severe weather
# 545        Natural    Meteorological         Severe weather
# 546        Natural    Meteorological  Blizzard/Winter storm
# 547        Natural    Climatological     Wildfire (General)
#
#                                               Location  Start Year  \
# 0    Crittenden, Daviess, Webster districts (Kentuc...        2000
# 1    Bullock, Montgomery districts (Alabama provinc...        2000
# 2                             Kentucky, Ohio provinces        2000
# 3    Gainesville, Alachua areas (Alachua district, ...        2000
# 4    Fort Worth Texas city (Tarrant district, Texas...        2000
# ..                                                 ...         ...
# 543  Portland City area (Oregon State); Snohomish a...        2023
# 544  Nashville City, Davidson County; Clarksville C...        2023
# 545  Massachusetts, Maine, New Jersey, New York, Pe...        2023
# 546  Pennsylvania, Massachusetts, New York, Oregon,...        2024
# 547                                    Texas, Oklahoma        2024
#
#      Total Deaths  No. Injured  Total Damage, Adjusted ('000 US$)
# 0             1.0         12.0                           356896.0
# 1            22.0        100.0                                NaN
# 2             3.0          NaN                                NaN
# 3             NaN          NaN                                NaN
# 4             5.0          NaN                           764777.0
# ..            ...          ...                                ...
# 543           3.0          NaN                                NaN
# 544           6.0         91.0                                NaN
# 545           7.0         12.0                                NaN
# 546          92.0          NaN                                NaN
# 547           2.0          NaN                                NaN
#
# [548 rows x 8 columns]

# %%
import re
# Define state names and their abbreviations
states = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO',
    'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH',
    'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC',
    'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT',
    'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

# Combine into a search pattern
state_pattern = re.compile(r'\b(' + '|'.join(re.escape(state) for state in states.keys()) + r'|\b' + '|'.join(re.escape(states[state]) for state in states) + r')\b', re.IGNORECASE)

# Function to extract states
def extract_states(location):
    matches = state_pattern.findall(location)
    unique_states = set(matches)  # Use set to remove duplicates
    # Convert abbreviations to full state names for uniformity
    full_names = {abbrev: name for name, abbrev in states.items()}
    final_states = {full_names.get(state.upper(), state.title()) for state in unique_states}
    return ', '.join(sorted(final_states))

# Example of applying the function
# Assuming 'df' is your DataFrame and 'Location' is the column with location data
df['Location'] = df['Location'].apply(extract_states)
df = df[df['Location'] != '']
df = df.fillna(0)
df
# Out:
#     Disaster Group Disaster Subgroup       Disaster Subtype  \
# 0          Natural    Meteorological                Tornado
# 1          Natural    Meteorological                Tornado
# 2          Natural      Hydrological         Riverine flood
# 3          Natural    Climatological            Forest fire
# 4          Natural    Meteorological                Tornado
# ..             ...               ...                    ...
# 543        Natural      Hydrological        Flood (General)
# 544        Natural    Meteorological         Severe weather
# 545        Natural    Meteorological         Severe weather
# 546        Natural    Meteorological  Blizzard/Winter storm
# 547        Natural    Climatological     Wildfire (General)
#
#                                               Location  Start Year  \
# 0                                             Kentucky        2000
# 1               Alabama, Arkansas, Georgia, Washington        2000
# 2                                       Kentucky, Ohio        2000
# 3                                              Florida        2000
# 4                                                Texas        2000
# ..                                                 ...         ...
# 543                                 Oregon, Washington        2023
# 544                    Connecticut, Indiana, Louisiana        2023
# 545  Maine, Massachusetts, New Jersey, New York, Pe...        2023
# 546  Arkansas, Illinois, Kentucky, Louisiana, Maine...        2024
# 547                                    Oklahoma, Texas        2024
#
#      Total Deaths  No. Injured  Total Damage, Adjusted ('000 US$)
# 0             1.0         12.0                           356896.0
# 1            22.0        100.0                                0.0
# 2             3.0          0.0                                0.0
# 3             0.0          0.0                                0.0
# 4             5.0          0.0                           764777.0
# ..            ...          ...                                ...
# 543           3.0          0.0                                0.0
# 544           6.0         91.0                                0.0
# 545           7.0         12.0                                0.0
# 546          92.0          0.0                                0.0
# 547           2.0          0.0                                0.0
#
# [537 rows x 8 columns]

# %%
df['Location'] = df['Location'].str.split(',')

# Calculate the number of locations in each row to divide quantitative values
df['Location_Count'] = df['Location'].apply(len)

# Explode the 'Location' column
expanded_df = df.explode('Location')

# Adjust the quantitative values by dividing by the number of locations
# Replace 'Total Deaths', 'Total Affected', or any other relevant columns as necessary
expanded_df['Total Deaths'] = round(expanded_df['Total Deaths'] / expanded_df['Location_Count'])
expanded_df['No. Injured'] = round(expanded_df['No. Injured'] / expanded_df['Location_Count'])
expanded_df["Total Damage, Adjusted ('000 US$)"] = round(expanded_df["Total Damage, Adjusted ('000 US$)"] / expanded_df['Location_Count'])

# Remove the temporary 'Location_Count' column if no longer needed
expanded_df.drop('Location_Count', axis=1, inplace=True)
expanded_df
# Out:
#     Disaster Group Disaster Subgroup       Disaster Subtype     Location  \
# 0          Natural    Meteorological                Tornado     Kentucky
# 1          Natural    Meteorological                Tornado      Alabama
# 1          Natural    Meteorological                Tornado     Arkansas
# 1          Natural    Meteorological                Tornado      Georgia
# 1          Natural    Meteorological                Tornado   Washington
# ..             ...               ...                    ...          ...
# 546        Natural    Meteorological  Blizzard/Winter storm    Tennessee
# 546        Natural    Meteorological  Blizzard/Winter storm   Washington
# 546        Natural    Meteorological  Blizzard/Winter storm    Wisconsin
# 547        Natural    Climatological     Wildfire (General)     Oklahoma
# 547        Natural    Climatological     Wildfire (General)        Texas
#
#      Start Year  Total Deaths  No. Injured  Total Damage, Adjusted ('000 US$)
# 0          2000           1.0         12.0                           356896.0
# 1          2000           6.0         25.0                                0.0
# 1          2000           6.0         25.0                                0.0
# 1          2000           6.0         25.0                                0.0
# 1          2000           6.0         25.0                                0.0
# ..          ...           ...          ...                                ...
# 546        2024           7.0          0.0                                0.0
# 546        2024           7.0          0.0                                0.0
# 546        2024           7.0          0.0                                0.0
# 547        2024           1.0          0.0                                0.0
# 547        2024           1.0          0.0                                0.0
#
# [2965 rows x 8 columns]

# %%
# Mapping dictionary for disaster subtypes
subtype_mapping = {
    # Flood related
    'Flood (General)': 'Flood',
    'Coastal flood': 'Flood',
    'Flash flood' : 'Flood',
    'Riverine flood' : 'Flood',

    # Storm related
    'Blizzard/Winter storm': 'Severe Storm',
    'Extra-tropical storm': 'Severe Storm',
    'Storm (General)': 'Severe Storm',
    'Lightning/Thunderstorms': 'Severe Storm',

    # Fire related
    'Forest fire': 'Wildfire',
    'Land fire (Brush, Bush, Pasture)': 'Wildfire',
    'Wildfire (General)': 'Wildfire',

    # Ground movement related
    'Ground movement': 'Earthquake',

    # Landslide related
    'Landslide (wet)': 'Landslide',
    'Mudslide': 'Landslide',

    # Tsunami remains the same, no need to add to the mapping unless there are variations of the name

    # Tornado related
    'Tornado': 'Tornado',
    'Tropical cyclone': 'Cyclone',
    # ... add all specific tornado and cyclone types here

    'Severe weather': 'Severe Weather',
}

# Replace the disaster subtypes with the new generalized categories
expanded_df['Disaster Subtype'] = expanded_df['Disaster Subtype'].replace(subtype_mapping)
expanded_df['Disaster Subtype'].unique()
# Out:
# array(['Tornado', 'Flood', 'Wildfire', 'Severe Weather', 'Earthquake',
#        'Cyclone', 'Severe Storm', 'Landslide'], dtype=object)

# %%
expanded_df['Location'] = expanded_df['Location'].str.strip()
expanded_df.to_excel('G2.xlsx', index=False)

# %%
expanded_df['Location'].unique()
# Out:
# array(['Kentucky', 'Alabama', 'Arkansas', 'Georgia', 'Washington', 'Ohio',
#        'Florida', 'Texas', 'Missouri', 'New Mexico', 'Oklahoma', 'Iowa',
#        'Louisiana', 'Wisconsin', 'Tennessee', 'Colorado', 'Alaska',
#        'Minnesota', 'Arizona', 'California', 'Idaho', 'Montana', 'Nevada',
#        'North Dakota', 'Oregon', 'South Dakota', 'Utah', 'Wyoming',
#        'New Jersey', 'Pennsylvania', 'New York', 'Hawaii',
#        'North Carolina', 'South Carolina', 'Virginia', 'Connecticut',
#        'Massachusetts', 'Mississippi', 'Rhode Island', 'Maryland',
#        'West Virginia', 'Illinois', 'Kansas', 'Nebraska', 'Maine',
#        'New Hampshire', 'Vermont', 'Indiana', 'Michigan', 'Delaware'],
#       dtype=object)

# %%
# Use Poisson distribution to estimate the probability of at least one flood next year
from scipy.stats import poisson
import json

def pred_disaster(Statename):

  years_of_data = expanded_df['Start Year'].max() - expanded_df['Start Year'].min()
  State_df = expanded_df[expanded_df['Location'] == Statename]
  Disasters = State_df['Disaster Subtype'].unique()

  prediction_results = {}

  for disaster in Disasters:
    disaster_count = State_df['Disaster Subtype'].value_counts()[disaster]
    # print(disaster, "prediction for next year", f"{1 - poisson.pmf(0, disaster_count/years_of_data):.2%}")
    prediction = 1 - poisson.pmf(0, disaster_count/years_of_data)
    prediction_results[disaster] = f"{prediction:.2%}"

  # Convert results to JSON
  prediction_json = json.dumps(prediction_results, indent=4)
  return prediction_json

# %%
print(pred_disaster('Illinois'))
# Out:
# {
#     "Tornado": "70.13%",
#     "Flood": "46.47%",
#     "Severe Storm": "81.11%",
#     "Cyclone": "4.08%",
#     "Severe Weather": "34.08%"
# }

# %%
print(pred_disaster('Montana'))
# Out:
# {
#     "Wildfire": "11.75%",
#     "Severe Storm": "36.77%",
#     "Tornado": "18.81%",
#     "Flood": "8.00%",
#     "Severe Weather": "11.75%",
#     "Cyclone": "4.08%"
# }
